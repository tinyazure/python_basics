# %% [markdown]
# <a href="https://colab.research.google.com/github/tinyazure/python_basics/blob/main/template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')

# %%
project_id = 'bigquerycourse-464720'

# %%
# %load_ext google.colab.data_table

# %%
# %%bigquery --project {project_id}
# SELECT
#   *
# FROM `bigquery-public-data.thelook_ecommerce.users`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
# ...
#           id   first_name  last_name                             email  age  \
# 0      98707        Jason      Sharp            jasonsharp@example.org   58
# 1      63035         Jill       Hale              jillhale@example.net   64
# 2      85614       Sandra    Sanchez         sandrasanchez@example.org   23
# 3      60885        Kayla    Sanders          kaylasanders@example.com   15
# 4      15848       Monica      Mills           monicamills@example.com   29
# ...      ...          ...        ...                               ...  ...
# 99995  53660       Sydney     Kramer          sydneykramer@example.net   61
# 99996  92898       Robert      Baker           robertbaker@example.net   50
# 99997  89630       Brenda     Harvey          brendaharvey@example.org   13
# 99998  44823       Dennis     Mooney          dennismooney@example.org   14
# ...
